# %%
import pandas as pd
import seaborn as sns
import os
from matplotlib import pyplot as plt 
# %matplotlib inline
import pandas_profiling
import numpy as np
from sklearn import neighbors, datasets
import matplotlib.pyplot as plt
import seaborn as sns
import random 
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_excel('C://Users//Stephanie//Desktop//dog proyect//Datos Posicionamiento.xlsx')
df1=pd.read_excel('C://Users//Stephanie//Desktop//dog proyect//Datos Posicionamiento.xlsx')

# %%
del df['Titulo']
del df['5 estrellas %']
del df['4 estrellas %']
del df['3 estrellas %']
del df['2 estrellas %']
del df['1 estrella %']
del df['Link']
df
# Out:
#      Posicionamiento                        Categoría     Color  \
# 0                905            Disfraces para perros      Rojo
# 1                898            Disfraces para perros      Rojo
# 2               1562            Disfraces para perros      Rojo
# 3                484            Disfraces para perros      Rojo
# 4                 29  Abrigos y chaquetas para perros      Azul
# ..               ...                              ...       ...
# 925               85            Disfraces para perros  Súperman
# 926                9            Disfraces para perros     Negro
# 927               72            Disfraces para perros     Negro
# 928               10            Disfraces para perros     Negro
# 929               55            Disfraces para perros     Negro
#
#                   Material  Precio Prime Tallas  \
# 0    Acrílico transpirable   14.99    Si      S
# 1    Acrílico transpirable   14.99    Si      M
# 2    Acrílico transpirable   14.99    Si      L
# ...

# %% [markdown]
# # Conversión de categóricas a numéricas

# %%
columna = "Categoría" 
keys=df['Categoría'] .unique()
values=range(len(keys))
Categoría=dict(zip(keys,values))
df['Categoría']=df['Categoría'].replace(Categoría)

columna = "Material" 
keys=df['Material'] .unique()
values=range(len(keys))
Material=dict(zip(keys,values))
df['Material']=df['Material'].replace(Material)

columna = "Color"
keys=df['Color'] .unique()
values=range(len(keys))
Color=dict(zip(keys,values))
df['Color']=df['Color'].replace(Color)

columna = "Prime"
keys=df['Prime'] .unique()
values=range(len(keys))
Prime=dict(zip(keys,values))
df['Prime']=df['Prime'].replace(Prime)

columna = "Epoca del año"
keys=df['Epoca del año'] .unique()
values=range(len(keys))
Epoca=dict(zip(keys,values))
df['Epoca del año']=df['Epoca del año'].replace(Epoca)

columna = "Tallas"
keys=df['Tallas'] .unique()
values=range(len(keys))
Tallas=dict(zip(keys,values))
df['Tallas']=df['Tallas'].replace(Tallas)

# %% [markdown]
# # Clustering con K-means

# %%
X = np.asarray(df[['Posicionamiento','Precio','Categoría','Color','Material','Prime','Tallas','Epoca del año','Valoraciones','Promedio Estrellas (5)','Antigüedad del producto']])

# %%
#K-MEANS 4
from sklearn.cluster import KMeans 
k_means = KMeans(init = "k-means++", n_clusters = 4, n_init = 12)
k_means.fit(X)
k_means_labels = k_means.labels_
k_means_cluster_centers = k_means.cluster_centers_
df["Clustering Clases"]=k_means_labels

# %%
dfcalor = df.loc[:,['Posicionamiento','Precio','Categoría','Color','Material','Prime','Tallas','Epoca del año','Valoraciones','Promedio Estrellas (5)','Antigüedad del producto','Clustering Clases']].corr()
fig, ax = plt.subplots(figsize=(10,8))
sns.heatmap(dfcalor, annot=True)

# %% [markdown]
# Se puede observar que las variables se agrupan por su posicionamiento ya que con kmeans=4 hay una correlacion de 0.48

# %%
#K-MEANS 4
from sklearn.cluster import KMeans 
k_means = KMeans(init = "k-means++", n_clusters = 2, n_init = 12)
k_means.fit(X)
k_means_labels = k_means.labels_
k_means_cluster_centers = k_means.cluster_centers_
df["Clustering Clases"]=k_means_labels

# %%
dfcalor = df.loc[:,['Posicionamiento','Precio','Categoría','Color','Material','Prime','Tallas','Epoca del año','Valoraciones','Promedio Estrellas (5)','Antigüedad del producto','Clustering Clases']].corr()
fig, ax = plt.subplots(figsize=(10,8))
sns.heatmap(dfcalor, annot=True)

# %%
Se puede observar que las variables se agrupan por su posicionamiento ya que con kmeans=2 hay una correlacion de 0.48
